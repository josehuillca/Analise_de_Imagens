# %% [markdown]
# <div class="container-fluid">
#   <div class="row">
#       <div class="col-md-1" align='center'>
#       </div>
#       <div class='col-md-9' align='center'>
#            <img src='images/title.png' />
#       </div>
#       <div class="col-md-2" align='center'></div>
#   </div>
# </div>

# %% [markdown]
# # Trabalho Práctico: Segmentação e clasificação de embarcações

# %% [markdown]
# ## Introdução
#
# Resumo do trabalho ...

# %% [markdown]
# ## Descrição do Problema
#
# Objetivos de trabalho ...

# %% [markdown]
# ## Carregando os Dados

# %%
from help_functions.HelpFunctions import *
import random

# %%
# ploting support stuff
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
image_path = "data/scale_images"
my_images = list_files_from_directory(image_path)

# %%
num_image = random.randint(0, len(my_images)-1)
my_img = image_read(image_path, my_images[num_image])
print("Name image({1}): {0} ...".format(my_images[num_image], num_image))
show_image_properties(my_img)
display_multiple_images([my_img], ["Imagem Original:"], 1, 1)
# Out:
# Name image(1): DSC_000009445.jpg ...
# properties    values
# ...
# width            1500
# height           1000
# channels            3
# # of pixels   4500000
# data type       uint8

# %% [markdown]
# ## Histogramas das bandas de uma imagem colorida

# %% [markdown]
# Uma representação em uma só banda (mono cromática). Verificando se há um espaço melhor para sua aplicação.

# %%
show_histogram_rgb(my_img, title="Histogramas da Imagem colorida separado por canal R,G B")
img_r, img_g, img_b = single_band_representation(my_img)

# %% [markdown]
# ## Equalização de Histograma

# %% [markdown]
# Comparar imagens originais com como elas ficam depois de processada por Equalização do Histograma.

# %%
histograms_equalization(img_r, img_g, img_b, compare_hist=True)

# %% [markdown]
# ## Mais experimentos com histogramas

# %% [markdown]
# Fazer processamentos experimentais diversos usando histograma.

# %% [markdown]
# ## System information

# %%
# %load_ext version_information
# %version_information numpy, matplotlib, cv2
# Out:
# Software versions
# Python 3.6.4 64bit [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]
# IPython 6.3.1
# OS Darwin 17.7.0 x86_64 i386 64bit
# numpy 1.14.2
# matplotlib 2.2.2
# cv2 4.0.0-pre
# Sat Oct 27 01:02:01 2018 -03
